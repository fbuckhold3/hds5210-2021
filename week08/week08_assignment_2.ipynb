# %% [markdown]
# # Week 7 Assignment
#
# _MkKinney 6.1_
#
# This week has been all about getting information off the internet both in structured data formats (CSV, JSON, etc) as well as HTML.  For these exercises, we're going to use two practical examples of fetching data from web pages to show how to use Pandas and BeautifulSoup to extract structured information from the web.
#
# ---
# ---

# %% [markdown]
# ### 33.1 Parsing a list in HTML
#
# Go to the Banner Health Price Transparency Page: https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency
#
# Notice that there is a list of hospitals and the city they are in.  We want to parse the underlying HTML to create a list of all the hospitals along with which city they're in.
#
# ```json
# [
#     ["Banner - University Medical Center Phoenix", "Arizona"],
#     ["Banner - University Medical Center South ", "Arizona"],
#     ...
# ]
# ```
#
# To examine the underlying HTML code, you can use Chrome, right-click, and choose **Inspect**.
#
# For reference, the documentation for BeautifulSoup is here: https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
from bs4 import BeautifulSoup
import requests
headers = { "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36" }

response = requests.get('https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency', headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
div = soup.find_all('div', {"class":"col-md-8"})[0]
for hospital_list in div.find_all('ul'):
    state = hospital_list.previous_sibling.previous_sibling.string
    for hospital in hospital_list.find_all('li'):
        print(state, hospital.text)
# Out:
# Arizona Banner - University Medical Center Phoenix
# Arizona Banner - University Medical Center South
# Arizona Banner - University Medical Center Tucson
# Arizona Banner Baywood Medical Center
# Arizona Banner Behavioral Health Hospital
# Arizona Banner Boswell Medical Center
# Arizona Banner Casa Grande Medical Center
# Arizona Banner Del E. Webb Medical Center
# Arizona Banner Desert Medical Center/Cardon Children's Medical Center
# Arizona Banner Estrella Medical Center
# Arizona Banner Gateway Medical Center/Banner MD Anderson Cancer Center
# Arizona Banner Goldfield Medical Center
# Arizona Banner Heart Hospital
# Arizona Banner Ironwood Medical Center
# Arizona Banner Ocotillo Medical Center
# Arizona Banner Payson Medical Center
# Arizona Banner Thunderbird Medical Center
# Arizona Page Hospital
# California Banner Lassen Medical Center
# Colorado Banner Fort Collins Medical Center
# Colorado McKee Medical Center
# Colorado North Colorado Medical Center
# Colorado Sterling Regional Medical Center
# Colorado East Morgan County Hospital
# Nebraska Ogallala Community Hospital
# Nevada Banner Churchill Community Hospital
# Wyoming Banner Wyoming Medical Center
# Wyoming Community Hospital
# Wyoming Washakie Medical Center
# Wyoming Platte County Memorial Hospital
# State-Specific Regulations Arizona
# State-Specific Regulations California
# State-Specific Regulations Colorado
# State-Specific Regulations Nebraska
# State-Specific Regulations Nevada
# State-Specific Regulations Wyoming

# %% [markdown]
# ---
#
# ### 33.2 Using Pandas to Read Tables
#
#
# Pandas documentation for loading data https://pandas.pydata.org/pandas-docs/version/0.23.4/api.html#input-output
#
# Pandas documentation for describing the shape of data https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.shape.html

# %%
import pandas as pd

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/Diagnosis-related_group')
print(tables)
# Out:
# [    0                                                  1
# 0 NaN  This article has multiple issues. Please help ...
# 1 NaN  This article needs to be updated. Please updat...
# 2 NaN  This article needs additional citations for ve...,     0                                                  1
# 0 NaN  This article needs to be updated. Please updat...,     0                                                  1
# 0 NaN  This article needs additional citations for ve...,    Hypothetical patient at Generic Hospital in San Francisco, CA, DRG 482, HIP & FEMUR PROCEDURES EXCEPT MAJOR JOINT W/O CC/MCC (2001)[15]:8  \
# 0                                         Description
# 1                              Average length of stay
# 2                      Large urban labor-related rate
# 3                       Large urban non-labor-related
# 4                                          Wage index
# 5   Standard Federal Rate: labor * wage index + no...
# 6                     DRG relative weight (RW) factor
# 7    Weighted payment: Standard Federal Rate * DRG RW
# 8                Disproportionate Share Payment (DSH)
# 9                    Indirect medical education (IME)
# 10                   Total cost outlier reimbursement
# 11  Total operating payment: Weighted payment * (1...
#
#    Hypothetical patient at Generic Hospital in San Francisco, CA, DRG 482, HIP & FEMUR PROCEDURES EXCEPT MAJOR JOINT W/O CC/MCC (2001)[15]:8.1
# 0                                               Value
# 1                                             3.8[16]
# 2                                           $2,809.18
# 3                                           $1,141.85
# 4                                              1.4193
# 5                                           $5,128.92
# 6                                              1.8128
# 7                                           $9,297.71
# 8                                              0.1413
# 9                                              0.0744
# 10                                                 $0
# 11                                         $11,303.23                                                                                           ,      Name  Version       Start date  \
# 0  MS-DRG       25  October 1, 2007
# 1  MS-DRG       26  October 1, 2008
# 2  MS-DRG       27  October 1, 2009
# 3  MS-DRG       31  October 1, 2013
# 4  MS-DRG       32  October 1, 2014
# 5  MS-DRG       33  October 1, 2015
# 6  MS-DRG       34  October 1, 2016
# 7  MS-DRG       35  October 1, 2017
#
#                                                Notes
# 0  Group numbers resequenced, so that for instanc...
# 1  One main change: implementation of Hospital Ac...
# 2  Changes involved are mainly related to Influen...
# 3                                                NaN
# 4                                                NaN
# 5            Convert from ICD-9-CM to ICD-10-CM.[17]
# 6  Address ICD-10 replication issues introduced i...
# 7  MS-DRGs 984 through 986 deleted and reassigned...  ]

# %%
for index,table in enumerate(tables):
    print("**************TABLE {}".format(index))
    print(table)
# Out:
# **************TABLE 0
#     0                                                  1
# 0 NaN  This article has multiple issues. Please help ...
# 1 NaN  This article needs to be updated. Please updat...
# 2 NaN  This article needs additional citations for ve...
# **************TABLE 1
#     0                                                  1
# 0 NaN  This article needs to be updated. Please updat...
# **************TABLE 2
#     0                                                  1
# 0 NaN  This article needs additional citations for ve...
# **************TABLE 3
#    Hypothetical patient at Generic Hospital in San Francisco, CA, DRG 482, HIP & FEMUR PROCEDURES EXCEPT MAJOR JOINT W/O CC/MCC (2001)[15]:8  \
# 0                                         Description
# 1                              Average length of stay
# 2                      Large urban labor-related rate
# 3                       Large urban non-labor-related
# 4                                          Wage index
# 5   Standard Federal Rate: labor * wage index + no...
# 6                     DRG relative weight (RW) factor
# 7    Weighted payment: Standard Federal Rate * DRG RW
# 8                Disproportionate Share Payment (DSH)
# 9                    Indirect medical education (IME)
# 10                   Total cost outlier reimbursement
# 11  Total operating payment: Weighted payment * (1...
#
#    Hypothetical patient at Generic Hospital in San Francisco, CA, DRG 482, HIP & FEMUR PROCEDURES EXCEPT MAJOR JOINT W/O CC/MCC (2001)[15]:8.1
# 0                                               Value
# 1                                             3.8[16]
# 2                                           $2,809.18
# 3                                           $1,141.85
# 4                                              1.4193
# 5                                           $5,128.92
# 6                                              1.8128
# 7                                           $9,297.71
# 8                                              0.1413
# 9                                              0.0744
# 10                                                 $0
# 11                                         $11,303.23
# **************TABLE 4
#      Name  Version       Start date  \
# 0  MS-DRG       25  October 1, 2007
# 1  MS-DRG       26  October 1, 2008
# 2  MS-DRG       27  October 1, 2009
# 3  MS-DRG       31  October 1, 2013
# 4  MS-DRG       32  October 1, 2014
# 5  MS-DRG       33  October 1, 2015
# 6  MS-DRG       34  October 1, 2016
# 7  MS-DRG       35  October 1, 2017
#
#                                                Notes
# 0  Group numbers resequenced, so that for instanc...
# 1  One main change: implementation of Hospital Ac...
# 2  Changes involved are mainly related to Influen...
# 3                                                NaN
# 4                                                NaN
# 5            Convert from ICD-9-CM to ICD-10-CM.[17]
# 6  Address ICD-10 replication issues introduced i...
# 7  MS-DRGs 984 through 986 deleted and reassigned...

# %%
drgs = tables[4]
drgs
# Out:
#      Name  Version       Start date  \
# 0  MS-DRG       25  October 1, 2007
# 1  MS-DRG       26  October 1, 2008
# 2  MS-DRG       27  October 1, 2009
# 3  MS-DRG       31  October 1, 2013
# 4  MS-DRG       32  October 1, 2014
# 5  MS-DRG       33  October 1, 2015
# 6  MS-DRG       34  October 1, 2016
# 7  MS-DRG       35  October 1, 2017
#
#                                                Notes
# 0  Group numbers resequenced, so that for instanc...
# 1  One main change: implementation of Hospital Ac...
# 2  Changes involved are mainly related to Influen...
# 3                                                NaN
# 4                                                NaN
# 5            Convert from ICD-9-CM to ICD-10-CM.[17]
# 6  Address ICD-10 replication issues introduced i...
# 7  MS-DRGs 984 through 986 deleted and reassigned...

# %% [markdown]
# ---
#
# ### 33.3 Find Something of Your Own
#
# Do some web searches and find an HTML page with some data that is interesting to something you're studying.  You can extract and parse that information using either BeautifulSoup or Pandas.  If you're using Pandas, then do something interesting to format and structure your data.  If you're using BeautifulSoup, you'll just need to do the work of parsing the data out of HTML -- that's hard enough!
#
# You don't need to build this as a function.  Just use notebook cells as I've done above.  You will be graded based on _style_.  Use variable names that make sense for your problem / solution. Cleanup anything you don't need before you submit your work.

# %%
# Your Code Here

#Created a table of the last 3 match years for the SLUSOM

# %%
import pandas as pd

# %%
match20 = pd.read_html('https://www.slu.edu/medicine/medical-education/md/match-list-2020.php')

for index, m20 in enumerate(match20):
   
    m20.loc[index, 'Match Year'] ='2020'
    m20.drop(df.loc[df['line_race']==0].index, inplace=True)
    
m20['Match Year'] = '2020'
# Out:
#          2020 Residency Appointments by Specialty                     \
#                                           Program          Specialty
# 0                        Cleveland Clinic Florida     Anesthesiology
# 1                      Brooke Army Medical Center     Anesthesiology
# 2            Ohio State University Medical Center     Anesthesiology
# 3                   UC Irvine Medical Center - CA     Anesthesiology
# 4              Oregon Health & Science University     Anesthesiology
# ..                                            ...                ...
# 169  HCA Houston Healthcare/University Houston-TX  Transitional Year
# 170     University Cincinnati Medical Center - OH            Urology
# 171         LSU Health Science Center, Shreveport            Urology
# 172        Penn State Hershey Medical Center - PA   Vascular Surgery
# 173                                           NaN                NaN
#
#     Match Year
#
# 0         2020
# 1         2020
# 2         2020
# 3         2020
# 4         2020
# ..         ...
# 169       2020
# 170       2020
# 171       2020
# 172       2020
# 173       2020
#
# [174 rows x 3 columns]

# %%
match19 = pd.read_html('https://www.slu.edu/medicine/medical-education/md/match-list-2019.php')

for index, m19 in enumerate(match19):
   
    m19.loc[index, 'Match Year'] ='2019'
    
m19['Match Year'] = '2019'

print(m19)
# Out:
#     2019 Residency Appointments by Specialty                    Match Year
#                                      Program          Specialty
# 0             Jackson Memorial Hospital - FL     Anesthesiology       2019
# 1                       Maine Medical Center     Anesthesiology       2019
# 2       Ohio State University Medical Center     Anesthesiology       2019
# 3        Rush University Medical Center - IL     Anesthesiology       2019
# 4              St. Louis University SOM - MO     Anesthesiology       2019
# ..                                       ...                ...        ...
# 172           Navy Medical Center Portsmouth  Transitional Year       2019
# 173            St. Louis University SOM - MO            Urology       2019
# 174             UC Davis Medical Center - CA            Urology       2019
# 175      University of Kansas Medical Center            Urology       2019
# 176                                      NaN                NaN       2019
#
# [177 rows x 3 columns]

# %%
match18 = pd.read_html('https://www.slu.edu/medicine/medical-education/md/match-list-2018.php')

for index, m18 in enumerate(match18):
   
    m18.loc[index, 'Match Year'] ='2018'
    
m18['Match Year'] = '2018'

# %%
slumatch = pd.concat([m18, m19, m20], axis = 1, keys = ['Program', 'Specialty', 'Match Year'])
slumatch.head(20)
# Out:
#                                     Program                                 \
#    2018 Residency Appointments by Specialty                     Match Year
#                                     Program           Specialty
# 0                     Barnes-Jewish Hosp-MO      Anesthesiology       2018
# 1                   Cleveland Clinic Fdn-OH      Anesthesiology       2018
# 2    Mayo Clinic School of Grad Med Educ-MN      Anesthesiology       2018
# 3           MedStar Georgetown Univ Hosp-DC      Anesthesiology       2018
# 4             Ohio State University Med Ctr      Anesthesiology       2018
# 5                      St Louis Univ SOM-MO      Anesthesiology       2018
# 6                   U Arizona COM at Tucson      Anesthesiology       2018
# 7                  U Iowa Hosps and Clinics      Anesthesiology       2018
# 8                U Michigan Hosps-Ann Arbor      Anesthesiology       2018
# 9                    U Utah Affil Hospitals      Anesthesiology       2018
# 10               Univ of Chicago Med Ctr-IL      Anesthesiology       2018
# 11               Vanderbilt Univ Med Ctr-TN      Anesthesiology       2018
# 12           Med Coll Wisconsin Affil Hosps     Child Neurology       2018
# 13                  U Tennessee COM-Memphis     Child Neurology       2018
# 14           Med Coll Wisconsin Affil Hosps         Dermatology       2018
# 15                 U Iowa Hosps and Clinics         Dermatology       2018
# 16             University Hosps-Columbia-MO         Dermatology       2018
# 17                  Baylor-Scott & White-TX  Emergency Medicine       2018
# 18   Mayo Clinic School of Grad Med Educ-MN  Emergency Medicine       2018
# 19                     St Louis Univ SOM-MO  Emergency Medicine       2018
#
#                                          Specialty                      \
#           2019 Residency Appointments by Specialty
#                                            Program           Specialty
# 0                   Jackson Memorial Hospital - FL      Anesthesiology
# 1                             Maine Medical Center      Anesthesiology
# 2             Ohio State University Medical Center      Anesthesiology
# 3              Rush University Medical Center - IL      Anesthesiology
# 4                    St. Louis University SOM - MO      Anesthesiology
# 5                    St. Louis University SOM - MO      Anesthesiology
# 6         University Michigan Hospital - Ann Arbor      Anesthesiology
# 7                        UC Irvine Med Center - CA      Anesthesiology
# 8                            UC San Francisco - CA      Anesthesiology
# 9                        UC Irvine Med Center - CA     Child Neurology
# 10             Kaiser Permanente - Los Angeles, CA         Dermatology
# 11                     Barnes Jewish Hospital - MO  Emergency Medicine
# 12   Creighton University Affiliated Hospital - AZ  Emergency Medicine
# 13                 Detroit Medical Center/WSU - MI  Emergency Medicine
# 14                  Stanford University Progs - CA  Emergency Medicine
# 15                  University Louisville SOM - KY  Emergency Medicine
# 16              University Maryland Medical Center  Emergency Medicine
# 17         University Massachusetts Medical School  Emergency Medicine
# 18  University Texas Southwestern Med Sch - Dallas  Emergency Medicine
# 19  University Texas Southwestern Med Sch - Dallas  Emergency Medicine
#
#                                                   Match Year  \
#    Match Year       2020 Residency Appointments by Specialty
#                                                      Program
# 0        2019                       Cleveland Clinic Florida
# 1        2019                     Brooke Army Medical Center
# 2        2019           Ohio State University Medical Center
# 3        2019                  UC Irvine Medical Center - CA
# 4        2019             Oregon Health & Science University
# 5        2019                 Northwestern McGaw/NMH/VA - IL
# 6        2019     NYP Hosp-Columbia Univ Medical Center - NY
# 7        2019                Harbor-UCLA Medical Center - CA
# 8        2019                      Childrens Hospital- LA-CA
# 9        2019  Medical College Wisconsin Affiliated Hospital
# 10       2019                    UPMC Medical Education - PA
# 11       2019                         Indiana University SOM
# 12       2019          University Iowa Hospitals and Clinics
# 13       2019      Wright State University Boonshoft SOM -OH
# 14       2019      University of Chicago Medical Center - IL
# 15       2019          Loyola University Medical Center - IL
# 16       2019           University Florida COM - Shands Hosp
# 17       2019         Baylor College Medicine - Houston - TX
# 18       2019              George Washington University - DC
# 19       2019               Hospital of the University of PA
#
#
#                        Match Year
#              Specialty
# 0       Anesthesiology       2020
# 1       Anesthesiology       2020
# 2       Anesthesiology       2020
# 3       Anesthesiology       2020
# 4       Anesthesiology       2020
# 5       Anesthesiology       2020
# 6       Anesthesiology       2020
# 7       Anesthesiology       2020
# 8      Child Neurology       2020
# 9      Child Neurology       2020
# 10     Child Neurology       2020
# 11         Dermatology       2020
# 12         Dermatology       2020
# 13         Dermatology       2020
# 14         Dermatology       2020
# 15         Dermatology       2020
# 16  Emergency Medicine       2020
# 17  Emergency Medicine       2020
# 18  Emergency Medicine       2020
# 19  Emergency Medicine       2020

# %% [markdown]
# ---
#
# ## Submitting Your Work
#
# In order to submit your work, you'll need to use the `git` command line program to **add** your homework file (this file) to your local repository, **commit** your changes to your local repository, and then **push** those changes up to github.com.  From there, I'll be able to **pull** the changes down and do my grading.  I'll provide some feedback, **commit** and **push** my comments back to you.  Next week, I'll show you how to **pull** down my comments.
#
# To run through everything one last time and submit your work:
# 1. Use the `Kernel` -> `Restart Kernel and Run All Cells` menu option to run everything from top to bottom and stop here.
# 2. Save this note with Ctrl-S (or Cmd-S)
# 2. Skip down to the last command cell (the one starting with `%%bash`) and run that cell.
#
# If anything fails along the way with this submission part of the process, let me know.  I'll help you troubleshoort.

# %%
assert False, "DO NOT REMOVE THIS LINE"

# %% [markdown]
# ---

# %%
# %%bash
# git pull
# git add week08_assignment_2.ipynb
# git commit -a -m "Submitting the week 8 programming assignment"
# git push

# %% [markdown]
# ---
#
# If the message above says something like _Submitting the week 8 programming assignment_ or _Everything is up to date_, then your work was submitted correctly.
